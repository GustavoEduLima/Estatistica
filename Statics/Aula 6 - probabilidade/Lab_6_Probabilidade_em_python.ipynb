# %% [markdown]
# ### **Laboratório I de Probabilidade em Python**
#
# Nesta atividade, os alunos irão aplicar os conceitos de probabilidade, espaço amostral e eventos no contexto do quadro de funcionários de uma empresa. Utilizando a tabela acima, deverão responder a perguntas sobre eventos simples, eventos mutuamente exclusivos e eventos não mutuamente exclusivos, implementando funções em Python para calcular as probabilidades correspondentes. O objetivo é consolidar a compreensão teórica e desenvolver habilidades práticas de programação e análise de dados probabilísticos em situações reais do ambiente corporativo.
# <br>
#
# **Objetivo**
#
# Ao finalizar esta atividade, espera-se que o aluno seja capaz de:
#
# * Compreender e identificar o espaço amostral e eventos em experimentos aleatórios;
# * Calcular probabilidades simples e de eventos mutuamente exclusivos a partir de dados organizados em tabelas;
# * Implementar funções em Python para automatizar o cálculo de probabilidades, utilizando estruturas de dados adequadas;
# * Interpretar resultados probabilísticos e relacioná-los com situações práticas;
# * Desenvolver o raciocínio lógico e a habilidade de resolução de problemas aplicando conceitos fundamentais de probabilidade

# %% [markdown]
# #### **1- O que é Probabilidade?**
#
# A probabilidade é o ramo da matemática que estuda a chance de ocorrência de eventos em experimentos aleatórios. Ela é usada para quantificar a incerteza e prever a possibilidade de diferentes resultados.
#
# $$
# P(A) = \frac{\text{número de casos favoráveis a } A}{\text{número total de casos possíveis}}
# $$
# <br>
# $$
# P(A) = \frac{n(A)}{n(S)}
# $$
#
# A onde:
# * $P(A)$: probabilidade do evento $A$
# * $n(A)$: número de casos favoráveis (evento $A$)
# * $n(S)$: número total de casos possíveis (espaço amostral)

# %% [markdown]
# #### **2- Espaço Amostral e Evento**
#
# #### **Espaço Amostral**
#
# O espaço amostral (denotado por $S$ ou $\Omega$) é o conjunto de todos os possíveis resultados de um experimento aleatório.
#
#
# **Exemplo 1:** <br>
# Ao lançar um dado de 6 faces, o espaço amostral é:
#
# $$S = \{1, 2, 3, 4, 5, 6\}$$
#
#
# **Exemplo 2:** <br>
#  Ao lançar uma moeda, o espaço amostral é:
#
# $$S = \{\text{cara}, \text{coroa} \}$$
#
#
# **Exemplo 3** <br>
# No caso de uma urna com bolas de diferentes características, cada bola é um elemento do espaço amostral.

# %% [markdown]
# #### **Evento**
#
# Um evento é qualquer subconjunto do espaço amostral. Ou seja, um evento é um ou mais resultados possíveis do experimento.
#
#
# Evento Simples: Contém apenas um resultado.
#
# **Exemplo 1:**<br>
#  "Sair o número 4 ao lançar um dado"
# Evento: $\{4\}$<br>
# Espaço amostral:$\{1,2,3,4,5,6\}$
#
# **Exemplo 2:**<br>
# "Seleção de uma pessoa em uma lista de chamada"
#
# Evento: Ser sorteado o aluno João.<br>
# Espaço amostral: Todos os alunos da lista.

# %% [markdown]
# #### **3- Eventos Mutuamente Exclusivos**
#
# Dois eventos são mutuamente exclusivos se não podem ocorrer ao mesmo tempo. Ou seja, a ocorrência de um impede a ocorrência do outro.
#
# <img src="data:image/png;base64,..." alt="imagem" width="250" height="120">
#
# **Probabilidade da União de Eventos Mutuamente Exclusivos**
#
# Se ($A$) e ($B$) são mutuamente exclusivos:
#
# $$
# P(A \text{ ou } B) = P(A) + P(B)
# $$
#
# $$
# P(A \cup B) = P(A) + P(B)
# $$
#
# Para mais de dois eventos:
#
# Evento mutuamente exclusivos ($ A_1, A_2, ..., A_n $):
#
# $$
# P(A_1 \text{ ou } A_2 \text{ ou } ... \text{ ou } A_n) = P(A_1) + P(A_2) + ... + P(A_n)
# $$
#
# <br>
#
# **Probabilidade da União de Eventos NÂO Mutuamente Exclusivos**
#
# <img src="data:image/png;base64,..." alt="imagem" width="220" height="130">
#
# Se ($A$) e ($B$) são eventos quaisquer (não necessariamente mutuamente exclusivos):
#
# $$
# P(A \text{ ou } B) = P(A) + P(B) - P(A \text{ e } B)
# $$
#
# $$
# P(A \cup B) = P(A) + P(B) - P(A \cap B)
# $$
#
#
# A onde:
#
# $P(A)$: probabilidade do evento $A$ ocorrer
#
# $P(B)$: probabilidade do evento $B$ ocorrer
#
# $P(A \cup B)$: probabilidade de ambos os eventos ocorrerem ao mesmo tempo (interseção)

# %%
# Exemplo de contagem uma lista numerica

lista1 = [1, 4, 6, 7, 9, 11, 13, 15, 17, 20, 25, 27]

contador1 = 0
for i in range(len(lista1)):
    if lista1[i] > 12:
        contador1 += 1
print(contador1)
# Out:
# 6

# %%
# Exemplo de contagem uma lista strings

lista2 = ["norte", "sul", "leste", "oeste", "norte", "sul", "norte", "sul", "oeste", "norte"]

contador2 = 0
for i in range(len(lista2)):
    if lista2[i] == "norte":
        contador2 += 1
print(contador2)
# Out:
# 4

# %% [markdown]
# ### **Tarefa**
#
# Tabela: Funcionários de uma Empresa
#
# | Nº | Nome      | Setor      | Cargo         | Turno    |
# |----|-----------|------------|--------------|----------|
# | 1  | Ana       | RH         | Analista     | Manhã    |
# | 2  | Bruno     | TI         | Desenvolvedor| Tarde    |
# | 3  | Carla     | Vendas     | Vendedor     | Manhã    |
# | 4  | Daniel    | TI         | Suporte      | Noite    |
# | 5  | Elisa     | RH         | Gerente      | Tarde    |
# | 6  | Felipe    | Vendas     | Gerente      | Manhã    |
# | 7  | Gabriela  | TI         | Desenvolvedor| Manhã    |
# | 8  | Henrique  | RH         | Analista     | Noite    |
# | 9  | Isabela   | Vendas     | Vendedor     | Tarde    |
# | 10 | João      | TI         | Suporte      | Manhã    |
# | 11 | Karla     | RH         | Analista     | Tarde    |
# | 12 | Lucas     | Vendas     | Gerente      | Noite    |
# | 13 | Mariana   | TI         | Desenvolvedor| Noite    |
# | 14 | Natan     | RH         | Gerente      | Manhã    |
# | 15 | Olivia    | Vendas     | Vendedor     | Noite    |

# %% [markdown]
# #### **Eventos Simples**
#
# **T1-** Qual a probabilidade de selecionar aleatoriamente o funcionário Daniel?

# %%
#### YOUR CODE HERE ####
ListaNome = [
    "Ana", "Bruno", "Carla", "Daniel", "Elisa", "Felipe", "Gabriela", "Henrique", "Isabela", "João", "Karla", "Lucas", "Mariana", "Natan", "Olivia"
]
contador = 0

for i in range(len(ListaNome)):
    if ListaNome[i] == "Daniel":
        contador += 1

print(contador/len(ListaNome))
# Out:
# 0.06666666666666667

# %% [markdown]
# **T2-** Qual a probabilidade de selecionar um funcionário do setor de RH que trabalhe no turno da noite?

# %%
#### YOUR CODE HERE ####
ListaSetor = [
    "RH", "TI" , "Vendas" , "TI" , "RH" , "Vendas" , "TI" , "RH" , "Vendas" , "TI" , "RH" , "Vendas" , "TI" , "RH" , "Vendas"
]
ListaTurno = [
    "Manhã", "Tarde" , "Manhã", "Noite" , "Tarde" , "Manhã", "Manhã", "Noite", "Tarde", "Manhã", "Tarde", "Noite", "Noite",  "Manhã", "Noite"
]

contador = 0
for i in range(len(ListaSetor)):
        if ListaSetor[i] == "RH" and ListaTurno[i] == "Noite":
            contador += 1

print(contador/len(ListaSetor)*len(ListaTurno))
# Out:
# 1.0

# %% [markdown]
# **T3-** Qual a probabilidade de selecionar um gerente do setor de Vendas?

# %%
#### YOUR CODE HERE ####
listaCargo = [
    "Analista", "Desenvolvedor", "Vendedor", "Suporte","Gerente", "Gerente", "Desenvolvedor", "Analista", "Vendedor", "Suporte", "Analista", "Gerente", "Desenvolvedor", "Gerente", "Vendedor"
]

contador = 0

for i in range(len(listaCargo)):
    if listaCargo[i] == "Gerente" and ListaSetor[i] == "Vendas":
        contador += 1

print(contador/len(listaCargo)*len(ListaSetor))
# Out:
# 2.0

# %% [markdown]
# **T4-** Qual a probabilidade de selecionar um desenvolvedor do setor de TI que trabalhe no turno da manhã?

# %%
#### YOUR CODE HERE ####
contador = 0

for i in range(len(listaCargo)):
    if listaCargo[i] == "Desenvolvedor" and ListaSetor[i] == "TI" and ListaTurno[i] == "Manhã":
        contador += 1

print(contador/len(listaCargo)*len(ListaSetor)*len(ListaTurno))
# Out:
# 15.0

# %% [markdown]
# #### **Eventos Mutuamente Exclusivos**
#
# **T5-** Qual a probabilidade de selecionar um funcionário do setor de RH ou do setor de Vendas?

# %%
#### YOUR CODE HERE ####
contador = 0

for i in range(len(ListaSetor)):
    if ListaSetor[i] == "RH" or ListaSetor[i] == "Vendas":
        contador += 1

print(contador/len(ListaSetor))
# Out:
# 0.6666666666666666

# %% [markdown]
# **T6-** Qual a probabilidade de selecionar um gerente ou um analista?

# %%
#### YOUR CODE HERE ####
contador = 0

for i in range(len(listaCargo)):
    if listaCargo[i] == "Gerente" or listaCargo[i] == "Analista":
        contador += 1

print(contador/len(listaCargo))
# Out:
# 0.4666666666666667

# %% [markdown]
# **T7-** Qual a probabilidade de selecionar um funcionário do turno da manhã ou do turno da noite?

# %%
#### YOUR CODE HERE ####
contador = 0

for i in range(len(ListaTurno)):
    if ListaTurno[i] == "Manhã" or ListaTurno[i] == "Noite":
        contador += 1

print(contador/len(ListaTurno))
# Out:
# 0.7333333333333333

# %% [markdown]
# **T8-** Qual a probabilidade de selecionar um funcionário do setor de TI ou do setor de RH?

# %%
#### YOUR CODE HERE ####
contador = 0

for i in range(len(ListaSetor)):
    if ListaSetor[i] == "TI" or ListaSetor[i] == "RH":
        contador += 1

print(contador/len(ListaSetor))
# Out:
# 0.6666666666666666

# %% [markdown]
# #### **Eventos Não Mutuamente Exclusivos**
#
# **T9-** Qual a probabilidade de selecionar um funcionário do setor de TI ou que trabalhe no turno da manhã?

# %%
#### YOUR CODE HERE ####
contador = 0

for i in range(len(ListaSetor)):
    if ListaSetor[i] == "TI" or ListaTurno[i] == "Manhã":
        contador += 1

print(contador/len(ListaSetor)*len(ListaTurno))
# Out:
# 9.0

# %% [markdown]
# **T10-** Qual a probabilidade de selecionar um gerente ou alguém que trabalhe no turno da noite?

# %%
#### YOUR CODE HERE ####
contador = 0

for i in range(len(listaCargo)):
    if listaCargo[i] == "Gerente" or ListaTurno[i] == "Noite":
        contador += 1

print(contador/len(listaCargo)*len(ListaTurno))
# Out:
# 8.0

# %% [markdown]
# **T11-** Qual a probabilidade de selecionar um analista ou alguém do setor de Vendas?

# %%
#### YOUR CODE HERE ####
contador = 0

for i in range(len(listaCargo)):
    if listaCargo[i] == "Analista" or ListaSetor[i] == "Vendas":
        contador += 1

print(contador/len(listaCargo)*len(ListaSetor))
# Out:
# 8.0

# %% [markdown]
# **T12-** Qual a probabilidade de selecionar um desenvolvedor ou alguém do turno da tarde?

# %%
#### YOUR CODE HERE ####
contador = 0

for i in range(len(listaCargo)):
    if listaCargo[i] == "Desenvolvedor" or ListaTurno[i] == "Tarde":
        contador += 1

print(contador/len(listaCargo)*len(ListaTurno))
# Out:
# 6.0
